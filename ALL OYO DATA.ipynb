# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## HYDERABAD :

# %%
names = []
address = []
city = []
features = []
ratings = []
votes = []
prices = []
for i in range(1,6):
        url="https://www.oyorooms.com/hotels-in-hyderabad/?page="+str (i)
        print(url)
        
        page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
        soup = BeautifulSoup(page.text, 'html.parser')
        
        N = soup.find_all("a", class_="c-nn640c u-width100")
        for i in N:
            a = i.text
            names.append(a)
        
        rat=soup.find_all('div',class_="oyo-cell--12-col listingHotelDescription__content")
        for i in rat:
            a = i.text
            b = re.findall("(\d\.\d)\s\(", a)
            ratings.append(b) 
        
        pr=soup.find_all("span",class_='listingPrice__finalPrice')
        for i in pr:
            a=i.text
            prices.append(a)  
       
        add=soup.find_all("span",class_="u-line--clamp-2")
        for i in add:
            a=i.text
            address.append(a.replace(', Hyderabad', ""))  
            
            
        vo=soup.find_all("div",class_="oyo-cell--12-col listingHotelDescription__content")
        for i in vo:
            a =i.text
            b = re.findall("\((\d+)\sRatings", a)
            votes.append(b)
        ci=soup.find_all("span",class_="u-line--clamp-2")
        for i in ci:
            a=i.text
            city.append(re.findall(r"Hyderabad", a)) 
            
            
        fea = soup.find_all("div", class_="amenityWrapper")
        for i in fea:
            a = i.text
            features.append(a.split("+")[0])
# Out:
# https://www.oyorooms.com/hotels-in-hyderabad/?page=1
# https://www.oyorooms.com/hotels-in-hyderabad/?page=2
# https://www.oyorooms.com/hotels-in-hyderabad/?page=3
# https://www.oyorooms.com/hotels-in-hyderabad/?page=4
# https://www.oyorooms.com/hotels-in-hyderabad/?page=5

# %%
print(len(names))
print(len(ratings))
print(len(prices))
print(len(address))
print(len(votes))
print(len(city))
print(len(features))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100

# %%
dic={"Hotel_Names":names,
   "Address":address,
   "City":city,
   "Ratings":ratings,
   "Votes":votes,
   "Prices":prices,
   "Features":features
  }

# %%
df=pd.DataFrame(dic)
df
# Out:
#                                     Hotel_Names  \
# 0                           Flagship Malkajgiri
# 1                OYO Flagship Hotel Lavish Stay
# 2       OYO Flagship Hotel Shazeb International
# 3   Collection O Hotel Rbs Kothapet-nagole Road
# 4    OYO Flagship 80983G RBS Square Langer Houz
# ..                                          ...
# 95         SPOT ON Hotel Sai Ashirwad Residency
# 96         OYO Flagship New Hotel Aroma Classic
# 97                  OYO Flagship Hotel R Square
# 98                   OYO Hotel Shannu Residency
# 99                 Townhouse 1188 Xanthe Hotels
#
#                                               Address                    City  \
# 0                                          Malkajgiri             [Hyderabad]
# 1                                    New Santoshnagar             [Hyderabad]
# 2                                           Telangana             [Hyderabad]
# 3                                                                 [Hyderabad]
# 4                                           Hyderabad  [Hyderabad, Hyderabad]
# ..                                                ...                     ...
# 95                                         punjagutta             [Hyderabad]
# 96                                   Hyderabad 500001  [Hyderabad, Hyderabad]
# 97                                   Dilsukhnagarnull             [Hyderabad]
# 98                 Near Apollo Pharmacy, Secunderabad             [Hyderabad]
# 99  Ward 98, Sai Baba Temple Road, Sr Nagar, Ward ...             [Hyderabad]
#
#    Ratings   Votes Prices                                   Features
# 0    [4.3]  [2269]   ₹699   Parking facility  Reception  Free Wifi
# 1    [4.3]    [23]   ₹582          Free Wifi  Geyser  Power backup
# 2    [3.7]    [17]   ₹699              Elevator  Free Wifi  Geyser
# 3    [5.0]     [7]   ₹699              Elevator  Free Wifi  Geyser
# 4    [3.9]    [98]   ₹699          Free Wifi  Geyser  Power backup
# ..     ...     ...    ...                                        ...
# 95      []      []  ₹1071          Free Wifi  Geyser  Power backup
# 96   [3.0]     [4]  ₹1062              Elevator  Free Wifi  Geyser
# 97   [4.0]   [214]  ₹1257          Free Wifi  Geyser  Power backup
# 98   [4.1]   [892]  ₹1074                     Free Wifi  Geyser  TV
# 99   [3.4]   [136]  ₹1484              Elevator  Free Wifi  Geyser
#
# [100 rows x 7 columns]

# %% [markdown]
# ## BANGLORE:

# %%
names = []
address = []
city = []
features = []
ratings = []
votes = []
prices = []
for i in range(1,6):
        url="https://www.oyorooms.com/hotels-in-bangalore/?page="+ str (i)
        print(url)
        page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
        soup = BeautifulSoup(page.text, 'html.parser')
        
        
        N = soup.find_all("a", class_="c-nn640c u-width100")
        for i in N:
            a = i.text
            names.append(a)
        
        rat=soup.find_all('div',class_="oyo-cell--12-col listingHotelDescription__content")
        for i in rat:
            a = i.text
            b = re.findall("(\d\.\d)\s\(", a)
            ratings.append(b) 
        
        pr=soup.find_all("span",class_='listingPrice__finalPrice')
        for i in pr:
            a=i.text
            prices.append(a)  
       
        add=soup.find_all("span",class_="u-line--clamp-2")
        for i in add:
            a=i.text
            address.append(a.replace(', Bangalore', ""))  
            
            
        vo=soup.find_all("div",class_="oyo-cell--12-col listingHotelDescription__content")
        for i in vo:
            a =i.text
            b = re.findall("\((\d+)\sRatings", a)
            votes.append(b)
        ci=soup.find_all("span",class_="u-line--clamp-2")
        for i in ci:
            a=i.text
            city.append(re.findall(r"Bangalore", a)) 
            
            
        fea = soup.find_all("div", class_="amenityWrapper")
        for i in fea:
            a = i.text
            features.append(a.split("+")[0])
# Out:
# https://www.oyorooms.com/hotels-in-bangalore/?page=1
# https://www.oyorooms.com/hotels-in-bangalore/?page=2
# https://www.oyorooms.com/hotels-in-bangalore/?page=3
# https://www.oyorooms.com/hotels-in-bangalore/?page=4
# https://www.oyorooms.com/hotels-in-bangalore/?page=5

# %%
print(len(names))
print(len(ratings))
print(len(prices))
print(len(address))
print(len(votes))
print(len(city))
print(len(features))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 98

# %% [markdown]
# ## FILLING NAN VALUE:

# %%
features.insert(95,np.NaN)
features.insert(98,np.NaN)

# %%
print(len(features))
# Out:
# 100

# %%
dic1={"Hotel_Names":names,
   "Address":address,
   "City":city,
   "Ratings":ratings,
   "Votes":votes,
   "Prices":prices,
   "Features":features
  }

# %%
df1=pd.DataFrame(dic1)
df1
# Out:
#                                           Hotel_Names  \
# 0   Home Shiva Shakthi Inn Near Ragigudda Sri Pras...
# 1   SPOT ON Srinivasa Boarding And Lodging Near Vi...
# 2   Flagship S M Residency Near Mysore Road Metro ...
# 3   OYO Flagship 814835 MANYATA INN SERVICE APARTMENT
# 4   SPOT ON Balaji Residency near Yeshwantupur Rai...
# ..                                                ...
# 95              Capital O Safari Rooms Near Snow City
# 96                        OYO 8501 ABHIMAANI COMFORTS
# 97  OYO Flagship V R Residency Near Sri Amruth Chi...
# 98  Flagship Sri Hari Premium Comforts Near Sandhy...
# 99                         OYO Flagship Raj Residency
#
#                                               Address                    City  \
# 0                                           J P Nagar             [Bangalore]
# 1                         Near N R Colony, Sajjepalya             [Bangalore]
# 2                                          Nagarbhavi             [Bangalore]
# 3                                          Karnataka              [Bangalore]
# 4                                          L N Colony             [Bangalore]
# ..                                                ...                     ...
# 95                     India Bangalore Karnatakaindia  [Bangalore, Bangalore]
# 96  Kanakpura main road metro pillar number 45 nea...                      []
# 97      Centrally Located, Near 4th block, HBR Layout             [Bangalore]
# 98               Near KLM Finvest, HSR layout sector7             [Bangalore]
# 99                                                                [Bangalore]
#
#    Ratings  Votes Prices                                         Features
# 0    [4.3]  [854]   ₹581   Private entrance  Parking facility  Elevator
# 1    [3.2]  [402]   ₹399                                              TV
# 2    [3.4]  [323]   ₹572                Free Wifi  Geyser  Power backup
# 3    [3.9]   [34]   ₹576                Free Wifi  Geyser  Power backup
# 4    [3.4]  [314]   ₹460                        AC  TV  Queen Sized Bed
# ..     ...    ...    ...                                              ...
# 95   [3.4]  [189]  ₹1202                                              NaN
# 96   [3.5]  [227]  ₹1360                    Elevator  Free Wifi  Geyser
# 97   [3.6]  [113]  ₹1216      Parking facility  Reception  Power backup
# 98   [3.4]  [260]  ₹1360                                              NaN
# 99   [3.0]    [4]  ₹1071                Free Wifi  Geyser  Power backup
#
# [100 rows x 7 columns]

# %% [markdown]
# ## DELHI:

# %%
names = []
address = []
city = []
features = []
ratings = []
votes = []
prices = []
for i in range(1,6):
        url="https://www.oyorooms.com/hotels-in-delhi/?page="+ str (i)
        print(url)
        page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
        soup = BeautifulSoup(page.text, 'html.parser')
        
        
        N = soup.find_all("a", class_="c-nn640c u-width100")
        for i in N:
            a = i.text
            names.append(a)
        
        rat=soup.find_all('div',class_="oyo-cell--12-col listingHotelDescription__content")
        for i in rat:
            a = i.text
            b = re.findall("(\d\.\d)\s\(", a)
            ratings.append(b) 
        
        pr=soup.find_all("span",class_='listingPrice__finalPrice')
        for i in pr:
            a=i.text
            prices.append(a)  
       
        add=soup.find_all("span",class_="u-line--clamp-2")
        for i in add:
            a=i.text
            address.append(a.replace(', Delhi', ""))  
            
            
        vo=soup.find_all("div",class_="oyo-cell--12-col listingHotelDescription__content")
        for i in vo:
            a =i.text
            b = re.findall("\((\d+)\sRatings", a)
            votes.append(b)
        ci=soup.find_all("span",class_="u-line--clamp-2")
        for i in ci:
            a=i.text
            city.append(re.findall(r"Delhi", a)) 
            
            
        fea = soup.find_all("div", class_="amenityWrapper")
        for i in fea:
            a = i.text
            features.append(a.split("+")[0])
# Out:
# https://www.oyorooms.com/hotels-in-delhi/?page=1
# https://www.oyorooms.com/hotels-in-delhi/?page=2
# https://www.oyorooms.com/hotels-in-delhi/?page=3
# https://www.oyorooms.com/hotels-in-delhi/?page=4
# https://www.oyorooms.com/hotels-in-delhi/?page=5

# %%
print(len(names))
print(len(ratings))
print(len(prices))
print(len(address))
print(len(votes))
print(len(city))
print(len(features))
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 99

# %%
features.insert(93,np.NaN)

# %%
print(len(features))
# Out:
# 100

# %%
dic2={"Hotel_Names":names,
   "Address":address,
   "City":city,
   "Ratings":ratings,
   "Votes":votes,
   "Prices":prices,
   "Features":features
  }

# %%
df2=pd.DataFrame(dic2)
df2
# Out:
#                                           Hotel_Names  \
# 0                  Flagship Dream Inn Near Akshardham
# 1           Townhouse 868 Dream Connect Near TDI Mall
# 2                        OYO Flagship Hotel SS Palace
# 3   Super OYO Townhouse 381 Dilshad Garden Near Di...
# 4                                     OYO Hotel J Joy
# ..                                                ...
# 95                              Flagship Leisurrestay
# 96                          OYO Flagship Golden Petal
# 97                                      OYO Happy Inn
# 98                 Collection O Hotel Swisston Palace
# 99                       OYO Flagship Hotel Vista Inn
#
#                                               Address            City Ratings  \
# 0   J 8  Near Mithila Appartment Chandra Vihar Pat...  [Delhi, Delhi]   [3.5]
# 1             Wz-3 Opp Pillor No 322 Moti Nagar Delhi  [Delhi, Delhi]   [4.2]
# 2                                             Block A         [Delhi]   [3.9]
# 3                                            Pocket E         [Delhi]   [4.3]
# 4         MAIN FAIZ ROAD (Above SBI BANK), KAROL BAGH              []   [3.6]
# ..                                                ...             ...     ...
# 95                                      I.P.Extension         [Delhi]   [3.5]
# 96                        Jheel Khurenja Geeta Colony         [Delhi]   [3.5]
# 97                        Near Shahdara Metro Station         [Delhi]   [3.5]
# 98  W.E.A Ajmal khan Road  Karol Bagh Near Metro P...         [Delhi]   [2.9]
# 99                                     WEA Karol Bagh         [Delhi]   [3.7]
#
#      Votes Prices                                          Features
# 0    [211]   ₹649                 Free Wifi  Geyser  Power backup
# 1   [2828]  ₹1248          Parking facility  Reception  Free Wifi
# 2    [284]   ₹904                                           AC  TV
# 3   [2219]  ₹1482                                           AC  TV
# 4   [1107]   ₹986                  Elevator  Reception  Free Wifi
# ..     ...    ...                                               ...
# 95     [9]  ₹2325                                           AC  TV
# 96    [16]  ₹2446                     Elevator  Free Wifi  Geyser
# 97    [52]  ₹2325   Private entrance  Parking facility  Reception
# 98    [19]  ₹2446                 Free Wifi  Geyser  Power backup
# 99     [4]  ₹2446                     Elevator  Free Wifi  Geyser
#
# [100 rows x 7 columns]

# %% [markdown]
# ## MUMBAI:

# %%
names = []
address = []
city = []
features = []
ratings = []
votes = []
prices = []
for i in range(1,5):
        url="https://www.oyorooms.com/hotels-in-mumbai/?page="+ str (i)
        print(url)
        page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
        soup = BeautifulSoup(page.text, 'html.parser')
        
        
        N = soup.find_all("a", class_="c-nn640c u-width100")
        for i in N:
            a = i.text
            names.append(a)
        
        rat=soup.find_all('div',class_="oyo-cell--12-col listingHotelDescription__content")
        for i in rat:
            a = i.text
            b = re.findall("(\d\.\d)\s\(", a)
            ratings.append(b) 
        
        pr=soup.find_all("span",class_='listingPrice__finalPrice')
        for i in pr:
            a=i.text
            prices.append(a)  
       
        add=soup.find_all("span",class_="u-line--clamp-2")
        for i in add:
            a=i.text
            address.append(a.replace(', Mumbai', ""))  
            
            
        vo=soup.find_all("div",class_="oyo-cell--12-col listingHotelDescription__content")
        for i in vo:
            a =i.text
            b = re.findall("\((\d+)\sRatings", a)
            votes.append(b)
        ci=soup.find_all("span",class_="u-line--clamp-2")
        for i in ci:
            a=i.text
            city.append(re.findall(r"Mumbai", a)) 
            
            
        fea = soup.find_all("div", class_="amenityWrapper")
        for i in fea:
            a = i.text
            features.append(a.split("+")[0])
# Out:
# https://www.oyorooms.com/hotels-in-mumbai/?page=1
# https://www.oyorooms.com/hotels-in-mumbai/?page=2
# https://www.oyorooms.com/hotels-in-mumbai/?page=3
# https://www.oyorooms.com/hotels-in-mumbai/?page=4

# %%
print(len(names))
print(len(ratings))
print(len(prices))
print(len(address))
print(len(votes))
print(len(city))
print(len(features))
# Out:
# 62
# 62
# 60
# 62
# 62
# 62
# 62

# %%
prices.insert(97,np.NaN)
prices.insert(88,np.NaN)

# %%
print(len(prices))
# Out:
# 62

# %%
dic3={"Hotel_Names":names,
   "Address":address,
   "City":city,
   "Ratings":ratings,
   "Votes":votes,
   "Prices":prices,
   "Features":features
  }

# %%
df3=pd.DataFrame(dic3)
df3
# Out:
#                                           Hotel_Names  \
# 0   Flagship The Mumbai Inn Near Chhatrapati Shiva...
# 1                  OYO Flagship 812940 Hotel Nk Grand
# 2     POP 81030D Hotel Crystal Park Jogeshwari Mumbai
# 3   OYO Flagship Hotel Kailash Park Near Chhatrapa...
# 4      Townhouse OAK Hotel Shubhangan Near Juhu Beach
# ..                                                ...
# 57           Collection O 815331 Hotel Galaxy Shelter
# 58              Capital O Hotel Pearl Near US Embassy
# 59  OYO Townhouse 810 Royal Palms Hotel - Daisy Co...
# 60  OYO Hotel Ak Palace Near Chhatrapati Shivaji I...
# 61             OYO Flagship Raj Hotel Near Juhu Beach
#
#                                               Address  \
# 0   The Mumbai Inn 90 Feet Road Next To Peninsula ...
# 1                                             Asalpha
# 2   SV ROAD, NEAR JVLR JUNCTION, NEXT TO MARKAZ HO...
# 3           Near Sakinaka Metro station, Andheri East
# 4                Hotel Shubhangan-21st road,Khar West
# ..                                                ...
# 57                 Prabhadevi. Appasaheb Marathe Marg
# 58             Near Wajan Kata Bus Stop, Indira Nagar
# 59                                           Goregaon
# 60  On main street, Near Asalpha Metro Station, Sa...
# 61                                          Santacruz
#
#                         City Ratings  Votes Prices  \
# 0   [Mumbai, Mumbai, Mumbai]   [3.4]  [418]  ₹1399
# 1                   [Mumbai]   [3.4]   [63]  ₹1359
# 2                         []   [3.7]   [74]  ₹1886
# 3                   [Mumbai]   [4.0]  [124]  ₹1722
# 4                         []   [3.5]   [63]  ₹2446
# ..                       ...     ...    ...    ...
# 57                  [Mumbai]   [3.6]   [10]  ₹3902
# 58                  [Mumbai]   [3.3]  [160]  ₹2896
# 59                  [Mumbai]   [3.6]  [494]  ₹3773
# 60                  [Mumbai]   [3.1]  [254]    NaN
# 61                  [Mumbai]   [3.1]  [191]    NaN
#
#                                            Features
# 0                 Hair Dryer  Reception  Security
# 1                 Free Wifi  Geyser  Power backup
# 2                 Free Wifi  Geyser  Power backup
# 3                 Free Wifi  Geyser  CCTV cameras
# 4    Reception  Ticket tour assistance  Caretaker
# ..                                              ...
# 57                    Elevator  Free Wifi  Geyser
# 58          Free Wifi  CCTV cameras  Card payment
# 59      Parking facility  Free Wifi  Power backup
# 60                                       Free Wifi
# 61                Free Wifi  Geyser  Power backup
#
# [62 rows x 7 columns]

# %% [markdown]
# ## CONCATE DATA FRAME :

# %%
CON1=pd.concat([df,df1],axis=0)
CON2=pd.concat([df2,df3],axis=0)

# %%
final=pd.concat([CON1,CON2],axis=0)

# %%
final
# Out:
#                                           Hotel_Names  \
# 0                                 Flagship Malkajgiri
# 1                      OYO Flagship Hotel Lavish Stay
# 2             OYO Flagship Hotel Shazeb International
# 3         Collection O Hotel Rbs Kothapet-nagole Road
# 4          OYO Flagship 80983G RBS Square Langer Houz
# ..                                                ...
# 57           Collection O 815331 Hotel Galaxy Shelter
# 58              Capital O Hotel Pearl Near US Embassy
# 59  OYO Townhouse 810 Royal Palms Hotel - Daisy Co...
# 60  OYO Hotel Ak Palace Near Chhatrapati Shivaji I...
# 61             OYO Flagship Raj Hotel Near Juhu Beach
#
#                                               Address                    City  \
# 0                                          Malkajgiri             [Hyderabad]
# 1                                    New Santoshnagar             [Hyderabad]
# 2                                           Telangana             [Hyderabad]
# 3                                                                 [Hyderabad]
# 4                                           Hyderabad  [Hyderabad, Hyderabad]
# ..                                                ...                     ...
# 57                 Prabhadevi. Appasaheb Marathe Marg                [Mumbai]
# 58             Near Wajan Kata Bus Stop, Indira Nagar                [Mumbai]
# 59                                           Goregaon                [Mumbai]
# 60  On main street, Near Asalpha Metro Station, Sa...                [Mumbai]
# 61                                          Santacruz                [Mumbai]
#
#    Ratings   Votes Prices                                      Features
# 0    [4.3]  [2269]   ₹699      Parking facility  Reception  Free Wifi
# 1    [4.3]    [23]   ₹582             Free Wifi  Geyser  Power backup
# 2    [3.7]    [17]   ₹699                 Elevator  Free Wifi  Geyser
# 3    [5.0]     [7]   ₹699                 Elevator  Free Wifi  Geyser
# 4    [3.9]    [98]   ₹699             Free Wifi  Geyser  Power backup
# ..     ...     ...    ...                                           ...
# 57   [3.6]    [10]  ₹3902                 Elevator  Free Wifi  Geyser
# 58   [3.3]   [160]  ₹2896       Free Wifi  CCTV cameras  Card payment
# 59   [3.6]   [494]  ₹3773   Parking facility  Free Wifi  Power backup
# 60   [3.1]   [254]    NaN                                    Free Wifi
# 61   [3.1]   [191]    NaN             Free Wifi  Geyser  Power backup
#
# [362 rows x 7 columns]

# %%
final=final.reset_index()

# %%
final
# Out:
#      index                                        Hotel_Names  \
# 0        0                                Flagship Malkajgiri
# 1        1                     OYO Flagship Hotel Lavish Stay
# 2        2            OYO Flagship Hotel Shazeb International
# 3        3        Collection O Hotel Rbs Kothapet-nagole Road
# 4        4         OYO Flagship 80983G RBS Square Langer Houz
# ..     ...                                                ...
# 357     57           Collection O 815331 Hotel Galaxy Shelter
# 358     58              Capital O Hotel Pearl Near US Embassy
# 359     59  OYO Townhouse 810 Royal Palms Hotel - Daisy Co...
# 360     60  OYO Hotel Ak Palace Near Chhatrapati Shivaji I...
# 361     61             OYO Flagship Raj Hotel Near Juhu Beach
#
#                                                Address  \
# 0                                           Malkajgiri
# 1                                     New Santoshnagar
# 2                                            Telangana
# 3
# 4                                            Hyderabad
# ..                                                 ...
# 357                 Prabhadevi. Appasaheb Marathe Marg
# 358             Near Wajan Kata Bus Stop, Indira Nagar
# 359                                           Goregaon
# 360  On main street, Near Asalpha Metro Station, Sa...
# 361                                          Santacruz
#
#                        City Ratings   Votes Prices  \
# 0               [Hyderabad]   [4.3]  [2269]   ₹699
# 1               [Hyderabad]   [4.3]    [23]   ₹582
# 2               [Hyderabad]   [3.7]    [17]   ₹699
# 3               [Hyderabad]   [5.0]     [7]   ₹699
# 4    [Hyderabad, Hyderabad]   [3.9]    [98]   ₹699
# ..                      ...     ...     ...    ...
# 357                [Mumbai]   [3.6]    [10]  ₹3902
# 358                [Mumbai]   [3.3]   [160]  ₹2896
# 359                [Mumbai]   [3.6]   [494]  ₹3773
# 360                [Mumbai]   [3.1]   [254]    NaN
# 361                [Mumbai]   [3.1]   [191]    NaN
#
#                                          Features
# 0        Parking facility  Reception  Free Wifi
# 1               Free Wifi  Geyser  Power backup
# 2                   Elevator  Free Wifi  Geyser
# 3                   Elevator  Free Wifi  Geyser
# 4               Free Wifi  Geyser  Power backup
# ..                                            ...
# 357                 Elevator  Free Wifi  Geyser
# 358       Free Wifi  CCTV cameras  Card payment
# 359   Parking facility  Free Wifi  Power backup
# 360                                    Free Wifi
# 361             Free Wifi  Geyser  Power backup
#
# [362 rows x 8 columns]

# %%
final.drop('index',axis=1,inplace=True)

# %%
final
# Out:
#                                            Hotel_Names  \
# 0                                  Flagship Malkajgiri
# 1                       OYO Flagship Hotel Lavish Stay
# 2              OYO Flagship Hotel Shazeb International
# 3          Collection O Hotel Rbs Kothapet-nagole Road
# 4           OYO Flagship 80983G RBS Square Langer Houz
# ..                                                 ...
# 357           Collection O 815331 Hotel Galaxy Shelter
# 358              Capital O Hotel Pearl Near US Embassy
# 359  OYO Townhouse 810 Royal Palms Hotel - Daisy Co...
# 360  OYO Hotel Ak Palace Near Chhatrapati Shivaji I...
# 361             OYO Flagship Raj Hotel Near Juhu Beach
#
#                                                Address  \
# 0                                           Malkajgiri
# 1                                     New Santoshnagar
# 2                                            Telangana
# 3
# 4                                            Hyderabad
# ..                                                 ...
# 357                 Prabhadevi. Appasaheb Marathe Marg
# 358             Near Wajan Kata Bus Stop, Indira Nagar
# 359                                           Goregaon
# 360  On main street, Near Asalpha Metro Station, Sa...
# 361                                          Santacruz
#
#                        City Ratings   Votes Prices  \
# 0               [Hyderabad]   [4.3]  [2269]   ₹699
# 1               [Hyderabad]   [4.3]    [23]   ₹582
# 2               [Hyderabad]   [3.7]    [17]   ₹699
# 3               [Hyderabad]   [5.0]     [7]   ₹699
# 4    [Hyderabad, Hyderabad]   [3.9]    [98]   ₹699
# ..                      ...     ...     ...    ...
# 357                [Mumbai]   [3.6]    [10]  ₹3902
# 358                [Mumbai]   [3.3]   [160]  ₹2896
# 359                [Mumbai]   [3.6]   [494]  ₹3773
# 360                [Mumbai]   [3.1]   [254]    NaN
# 361                [Mumbai]   [3.1]   [191]    NaN
#
#                                          Features
# 0        Parking facility  Reception  Free Wifi
# 1               Free Wifi  Geyser  Power backup
# 2                   Elevator  Free Wifi  Geyser
# 3                   Elevator  Free Wifi  Geyser
# 4               Free Wifi  Geyser  Power backup
# ..                                            ...
# 357                 Elevator  Free Wifi  Geyser
# 358       Free Wifi  CCTV cameras  Card payment
# 359   Parking facility  Free Wifi  Power backup
# 360                                    Free Wifi
# 361             Free Wifi  Geyser  Power backup
#
# [362 rows x 7 columns]

# %%
final.to_csv("ALL_OYO_RAW_DATA.csv")

# %% [markdown]
# ## DATA CLEANING:

# %%
data=pd.read_csv(r"C:\\Users\\amarn\\ALL_OYO_RAW_DATA.csv")

# %%
data
# Out:
#      Unnamed: 0                                        Hotel_Names  \
# 0             0                                Flagship Malkajgiri
# 1             1                     OYO Flagship Hotel Lavish Stay
# 2             2            OYO Flagship Hotel Shazeb International
# 3             3        Collection O Hotel Rbs Kothapet-nagole Road
# 4             4         OYO Flagship 80983G RBS Square Langer Houz
# ..          ...                                                ...
# 357         357           Collection O 815331 Hotel Galaxy Shelter
# 358         358              Capital O Hotel Pearl Near US Embassy
# 359         359  OYO Townhouse 810 Royal Palms Hotel - Daisy Co...
# 360         360  OYO Hotel Ak Palace Near Chhatrapati Shivaji I...
# 361         361             OYO Flagship Raj Hotel Near Juhu Beach
#
#                                                Address  \
# 0                                           Malkajgiri
# 1                                     New Santoshnagar
# 2                                            Telangana
# 3                                                  NaN
# 4                                            Hyderabad
# ..                                                 ...
# 357                 Prabhadevi. Appasaheb Marathe Marg
# 358             Near Wajan Kata Bus Stop, Indira Nagar
# 359                                           Goregaon
# 360  On main street, Near Asalpha Metro Station, Sa...
# 361                                          Santacruz
#
#                            City  Ratings     Votes Prices  \
# 0                 ['Hyderabad']  ['4.3']  ['2269']   ₹699
# 1                 ['Hyderabad']  ['4.3']    ['23']   ₹582
# 2                 ['Hyderabad']  ['3.7']    ['17']   ₹699
# 3                 ['Hyderabad']  ['5.0']     ['7']   ₹699
# 4    ['Hyderabad', 'Hyderabad']  ['3.9']    ['98']   ₹699
# ..                          ...      ...       ...    ...
# 357                  ['Mumbai']  ['3.6']    ['10']  ₹3902
# 358                  ['Mumbai']  ['3.3']   ['160']  ₹2896
# 359                  ['Mumbai']  ['3.6']   ['494']  ₹3773
# 360                  ['Mumbai']  ['3.1']   ['254']    NaN
# 361                  ['Mumbai']  ['3.1']   ['191']    NaN
#
#                                          Features
# 0        Parking facility  Reception  Free Wifi
# 1               Free Wifi  Geyser  Power backup
# 2                   Elevator  Free Wifi  Geyser
# 3                   Elevator  Free Wifi  Geyser
# 4               Free Wifi  Geyser  Power backup
# ..                                            ...
# 357                 Elevator  Free Wifi  Geyser
# 358       Free Wifi  CCTV cameras  Card payment
# 359   Parking facility  Free Wifi  Power backup
# 360                                    Free Wifi
# 361             Free Wifi  Geyser  Power backup
#
# [362 rows x 8 columns]

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data
# Out:
#                                            Hotel_Names  \
# 0                                  Flagship Malkajgiri
# 1                       OYO Flagship Hotel Lavish Stay
# 2              OYO Flagship Hotel Shazeb International
# 3          Collection O Hotel Rbs Kothapet-nagole Road
# 4           OYO Flagship 80983G RBS Square Langer Houz
# ..                                                 ...
# 357           Collection O 815331 Hotel Galaxy Shelter
# 358              Capital O Hotel Pearl Near US Embassy
# 359  OYO Townhouse 810 Royal Palms Hotel - Daisy Co...
# 360  OYO Hotel Ak Palace Near Chhatrapati Shivaji I...
# 361             OYO Flagship Raj Hotel Near Juhu Beach
#
#                                                Address  \
# 0                                           Malkajgiri
# 1                                     New Santoshnagar
# 2                                            Telangana
# 3                                                  NaN
# 4                                            Hyderabad
# ..                                                 ...
# 357                 Prabhadevi. Appasaheb Marathe Marg
# 358             Near Wajan Kata Bus Stop, Indira Nagar
# 359                                           Goregaon
# 360  On main street, Near Asalpha Metro Station, Sa...
# 361                                          Santacruz
#
#                            City  Ratings     Votes Prices  \
# 0                 ['Hyderabad']  ['4.3']  ['2269']   ₹699
# 1                 ['Hyderabad']  ['4.3']    ['23']   ₹582
# 2                 ['Hyderabad']  ['3.7']    ['17']   ₹699
# 3                 ['Hyderabad']  ['5.0']     ['7']   ₹699
# 4    ['Hyderabad', 'Hyderabad']  ['3.9']    ['98']   ₹699
# ..                          ...      ...       ...    ...
# 357                  ['Mumbai']  ['3.6']    ['10']  ₹3902
# 358                  ['Mumbai']  ['3.3']   ['160']  ₹2896
# 359                  ['Mumbai']  ['3.6']   ['494']  ₹3773
# 360                  ['Mumbai']  ['3.1']   ['254']    NaN
# 361                  ['Mumbai']  ['3.1']   ['191']    NaN
#
#                                          Features
# 0        Parking facility  Reception  Free Wifi
# 1               Free Wifi  Geyser  Power backup
# 2                   Elevator  Free Wifi  Geyser
# 3                   Elevator  Free Wifi  Geyser
# 4               Free Wifi  Geyser  Power backup
# ..                                            ...
# 357                 Elevator  Free Wifi  Geyser
# 358       Free Wifi  CCTV cameras  Card payment
# 359   Parking facility  Free Wifi  Power backup
# 360                                    Free Wifi
# 361             Free Wifi  Geyser  Power backup
#
# [362 rows x 7 columns]
